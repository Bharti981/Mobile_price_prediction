# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
#warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Bharti Jagyasi\Downloads\Processed_Flipdata.csv")
df
#To read the CSV File
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
#     Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0          13MP          5MP        1          16.76
# 1          13MP          5MP        1          16.76
# 2          50MP         16MP        0          16.64
# 3           8MP          5MP        0          16.56
# 4          50MP          5MP        1          16.76
# ..          ...          ...      ...            ...
# 536        50MP         12MP        0          15.49
# 537         5MP          2MP        0          12.70
# 538        50MP          8MP        0          16.76
# 539        50MP         32MP        0          16.26
# 540        50MP          8MP        0          16.66
#
#                       Processor_   Prize
# 0     Unisoc Spreadtrum SC9863A1   7,299
# 1     Unisoc Spreadtrum SC9863A1   7,299
# 2        Qualcomm Snapdragon 680  11,999
# 3             Mediatek Helio A22   5,649
# 4                            G37   8,999
# ..                           ...     ...
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# 539      Exynos 1380, Octa Core   38,999
# 540           Mediatek Helio G35  15,999
#
# [541 rows x 12 columns]

# %% [markdown]
#  Check datatype information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
df.shape
# Out:
# (541, 12)

# %%
df.head(5)
# Out:
#    Unnamed: 0            Model        Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7   Night Black      64    4      6000
# 1           1  Infinix SMART 7    Azure Blue      64    4      6000
# 2           2     MOTOROLA G32  Mineral Gray     128    8      5000
# 3           3         POCO C50    Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i      Marigold     128    8      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# 2        50MP         16MP        0          16.64
# 3         8MP          5MP        0          16.56
# 4        50MP          5MP        1          16.76
#
#                    Processor_   Prize
# 0  Unisoc Spreadtrum SC9863A1   7,299
# 1  Unisoc Spreadtrum SC9863A1   7,299
# 2     Qualcomm Snapdragon 680  11,999
# 3          Mediatek Helio A22   5,649
# 4                         G37   8,999

# %%
df.tail()
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
#     Rear Camera Front Camera  AI Lens  Mobile Height  \
# 536        50MP         12MP        0          15.49
# 537         5MP          2MP        0          12.70
# 538        50MP          8MP        0          16.76
# 539        50MP         32MP        0          16.26
# 540        50MP          8MP        0          16.66
#
#                       Processor_   Prize
# 536  Qualcomm Snapdragon 8 Gen 2  79,999
# 537                    Octa Core   5,998
# 538           MediaTek Helio G35   9,990
# 539      Exynos 1380, Octa Core   38,999
# 540           Mediatek Helio G35  15,999

# %%
df.ndim
#check dimension of the dataset
# Out:
# 2

# %%
#df=df.drop(["Unnamed: 0"],axis=1)
df=df.drop(['Unnamed: 0'],axis=1)

# %%
df.describe()
# Out:
#            Memory         RAM     Battery_     AI Lens  Mobile Height
# count  541.000000  541.000000   541.000000  541.000000     541.000000
# mean   110.550832    5.397412  4871.587800    0.062847      16.431201
# std     60.600694    1.984923   780.148862    0.242911       2.523553
# min     16.000000    2.000000   800.000000    0.000000       4.500000
# 25%     64.000000    4.000000  5000.000000    0.000000      16.510000
# 50%    128.000000    6.000000  5000.000000    0.000000      16.710000
# 75%    128.000000    8.000000  5000.000000    0.000000      16.940000
# max    256.000000    8.000000  7000.000000    1.000000      41.940000

# %%
df.iloc[25:38]
# Out:
#                  Model          Colour  Memory  RAM  Battery_ Rear Camera  \
# 25         vivo T2x 5G   Glimmer Black     128    6      5000        50MP
# 26         vivo T2x 5G     Marine Blue     128    4      5000        50MP
# 27         vivo T2x 5G     Marine Blue     128    6      5000        50MP
# 28  Infinix Smart 7 HD     Green Apple      64    2      5000         8MP
# 29           REDMI A1+           Black      32    3      5000         8MP
# 30           REDMI A1+      Light Blue      32    3      5000         8MP
# 31            POCO C55     Power Black      64    4      5000        50MP
# 32           REDMI A1+     Light Green      32    3      5000         8MP
# 33            POCO C55       Cool Blue      64    4      5000        50MP
# 34            POCO C55    Forest Green      64    4      5000        50MP
# 35            POCO C55       Cool Blue     128    6      5000        50MP
# 36  SAMSUNG Galaxy F13  Nightsky Green      64    4      6000        50MP
# 37  SAMSUNG Galaxy F13  Nightsky Green     128    4      6000        50MP
#
#    Front Camera  AI Lens  Mobile Height           Processor_   Prize
# 25          8MP        0          16.71       Dimensity 6020  13,999
# 26          8MP        0          16.71       Dimensity 6020  12,999
# 27          8MP        0          16.71       Dimensity 6020  13,999
# 28          5MP        1          16.76  Spreadtrum SC9863A1   6,199
# 29          5MP        0          16.56   Mediatek Helio A22   6,599
# 30          5MP        0          16.56   Mediatek Helio A22   6,599
# 31          5MP        0          17.04   Mediatek Helio G85   7,749
# 32          5MP        0          16.56   Mediatek Helio A22   6,599
# 33          5MP        0          17.04   Mediatek Helio G85   7,749
# 34          5MP        0          17.04   Mediatek Helio G85   7,749
# 35          5MP        0          17.04   Mediatek Helio G85   8,999
# 36          8MP        0          16.76           Exynos 850   9,699
# 37          8MP        0          16.76           Exynos 850  10,699

# %%
df.columns
# Out:
# Index(['Model', 'Colour', 'Memory', 'RAM', 'Battery_', 'Rear Camera',
#        'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_', 'Prize'],
#       dtype='object')

# %% [markdown]
# Rename Prize column to Price

# %%
df.rename(columns={'Prize':'Price'},inplace=True)

# %%
df.iloc[:7,:15]
# Out:
#              Model        Colour  Memory  RAM  Battery_ Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000        13MP
# 1  Infinix SMART 7    Azure Blue      64    4      6000        13MP
# 2     MOTOROLA G32  Mineral Gray     128    8      5000        50MP
# 3         POCO C50    Royal Blue      32    2      5000         8MP
# 4  Infinix HOT 30i      Marigold     128    8      5000        50MP
# 5  Infinix HOT 30i  Glacier Blue     128    8      5000        50MP
# 6  Infinix HOT 30i  Mirror Black     128    8      5000        50MP
#
#   Front Camera  AI Lens  Mobile Height                  Processor_   Price
# 0          5MP        1          16.76  Unisoc Spreadtrum SC9863A1   7,299
# 1          5MP        1          16.76  Unisoc Spreadtrum SC9863A1   7,299
# 2         16MP        0          16.64     Qualcomm Snapdragon 680  11,999
# 3          5MP        0          16.56          Mediatek Helio A22   5,649
# 4          5MP        1          16.76                         G37   8,999
# 5          5MP        1          16.76                         G37   8,999
# 6          5MP        1          16.76                         G37   8,999

# %% [markdown]
# Extract MP from Both the columns of camera

# %%
import re
def int_extracter(x):
    return re.search('\d+',x).group()

# %% [markdown]
# Apply function to Rear Camera columns usning lambda function

# %%
df['Rear Camera'] = df['Rear Camera'].apply(lambda x:int_extracter(x))

# %%
df['Front Camera'] = df['Front Camera'].apply(lambda x:int_extracter(x))

# %%
df.head(5)
# Out:
#              Model        Colour  Memory  RAM  Battery_ Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000          13
# 1  Infinix SMART 7    Azure Blue      64    4      6000          13
# 2     MOTOROLA G32  Mineral Gray     128    8      5000          50
# 3         POCO C50    Royal Blue      32    2      5000           8
# 4  Infinix HOT 30i      Marigold     128    8      5000          50
#
#   Front Camera  AI Lens  Mobile Height                  Processor_   Price
# 0            5        1          16.76  Unisoc Spreadtrum SC9863A1   7,299
# 1            5        1          16.76  Unisoc Spreadtrum SC9863A1   7,299
# 2           16        0          16.64     Qualcomm Snapdragon 680  11,999
# 3            5        0          16.56          Mediatek Helio A22   5,649
# 4            5        1          16.76                         G37   8,999

# %% [markdown]
# Convert data type of Both Camera columns and Price column by numerical

# %%
df['Price'] = df['Price'].str.replace(',', '').astype(float)

# %%
df['Rear Camera'] = df['Rear Camera'].astype(int)
df['Front Camera'] = df['Front Camera'].astype(int)

# %%
df.head(3)
# Out:
#              Model        Colour  Memory  RAM  Battery_  Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000           13
# 1  Infinix SMART 7    Azure Blue      64    4      6000           13
# 2     MOTOROLA G32  Mineral Gray     128    8      5000           50
#
#    Front Camera  AI Lens  Mobile Height                  Processor_    Price
# 0             5        1          16.76  Unisoc Spreadtrum SC9863A1   7299.0
# 1             5        1          16.76  Unisoc Spreadtrum SC9863A1   7299.0
# 2            16        0          16.64     Qualcomm Snapdragon 680  11999.0

# %%
df.describe()
# Out:
#            Memory         RAM     Battery_  Rear Camera  Front Camera  \
# count  541.000000  541.000000   541.000000   541.000000    541.000000
# mean   110.550832    5.397412  4871.587800    46.110906     11.992606
# std     60.600694    1.984923   780.148862    31.260416      9.053746
# min     16.000000    2.000000   800.000000     0.000000      0.000000
# 25%     64.000000    4.000000  5000.000000    13.000000      5.000000
# 50%    128.000000    6.000000  5000.000000    50.000000      8.000000
# 75%    128.000000    8.000000  5000.000000    50.000000     16.000000
# max    256.000000    8.000000  7000.000000   200.000000     60.000000
#
#           AI Lens  Mobile Height         Price
# count  541.000000     541.000000    541.000000
# mean     0.062847      16.431201  16228.375231
# std      0.242911       2.523553  10793.588322
# min      0.000000       4.500000    920.000000
# 25%      0.000000      16.510000   9290.000000
# 50%      0.000000      16.710000  13499.000000
# 75%      0.000000      16.940000  19280.000000
# max      1.000000      41.940000  80999.000000

# %% [markdown]
# Check Null values

# %%
df.isnull().sum()
# Out:
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Price            0
# dtype: int64

# %% [markdown]
# Check Outliers

# %%
sns.boxplot(data = df,y = 'Price')
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# Handle outliers in column with IQR method by capping

# %%
def iqr_technique(DFcolumn):
    Q1 = np.percentile(DFcolumn, 25)
    Q3 = np.percentile(DFcolumn, 75)
    IQR = Q3 - Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range, upper_range

# %%
lower_limit_iqr,upper_limit_iqr = iqr_technique(df['Price'])

# %%
df['Price'] = np.where(df['Price']>upper_limit_iqr,upper_limit_iqr,np.where(df['Price']<lower_limit_iqr,lower_limit_iqr,df['Price']))

# %% [markdown]
# # Box plot of price after handling outliers

# %%
sns.boxplot(data = df,y = 'Price')
# Out:
# <Axes: ylabel='Price'>

# %% [markdown]
# Check duplicate Values in Dataset and remove them

# %%
print("\nDuplicate Rows:")
print(df[df.duplicated()])
# Out:
# Duplicate Rows:
#                      Model          Colour  Memory  RAM  Battery_  \
# 27             vivo T2x 5G     Marine Blue     128    6      5000
# 48            MOTOROLA e32     Arctic Blue      64    4      5000
# 91   SAMSUNG Galaxy F14 5G   B.A.E. Purple     128    4      6000
# 132  SAMSUNG Galaxy F14 5G       OMG Black     128    6      6000
# 247              redmi min             M3)      16    4      1000
# 344         Tecno Spark 9T  Turquoise Cyan      64    4      5000
# 352         POCO X4 Pro 5G     Laser Black     128    8      5000
# 424            realme C30s    Stripe Black      64    4      5000
# 437           vivo Y100 5G    Pacific Blue     128    8      4500
# 480               POCO C31      Royal Blue      64    4      5000
#
#      Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 27            50             8        0          16.71
# 48            50             8        0          16.51
# 91            50            13        0          16.76
# 132           50            13        0          16.76
# 247            0             0        0           4.57
# 344           50             8        0          16.76
# 352           64            16        0          16.94
# 424            8             5        0          16.51
# 437           64            16        0          16.21
# 480           13             5        0          16.59
#
#                           Processor_    Price
# 27                    Dimensity 6020  13999.0
# 48                Mediatek Helio G37   7999.0
# 91           Exynos 1330, Octa Core   13490.0
# 132          Exynos 1330, Octa Core   14490.0
# 247                       Spreadtrum    920.0
# 344               MediaTek Helio G35   9290.0
# 352       Qualcomm Snapdragon 695 5G  19499.0
# 424  Unisoc SC9863A/ Unisoc SC9863A1   8499.0
# 437           Mediatek Dimensity 900  23999.0
# 480                     MediaTek G35   8999.0

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Visualize the relation between Phone price and AI Lens

# %%
sns.scatterplot(data = df,x = 'Price',y= 'AI Lens')
plt.title(' Relation between Mobile Price and AI Lens\n')
plt.show()

# %% [markdown]
# No information through AI lens

# %% [markdown]
# Visualize the relation between Phone price and Mobile Height

# %%
sns.scatterplot(data = df,x = 'Price',y= 'Mobile Height')
plt.title('Relation between Price of Phone and Mobile Height\n')
plt.show()

# %% [markdown]
# No meaningful information through Mobile height

# %% [markdown]
# Remove AI Lens and Mobile hight columns as these features are not affecting the price of Mobile

# %%
df.drop(['AI Lens','Mobile Height'],axis = 1, inplace=True)

# %%
df.head(5)
# Out:
#              Model        Colour  Memory  RAM  Battery_  Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000           13
# 1  Infinix SMART 7    Azure Blue      64    4      6000           13
# 2     MOTOROLA G32  Mineral Gray     128    8      5000           50
# 3         POCO C50    Royal Blue      32    2      5000            8
# 4  Infinix HOT 30i      Marigold     128    8      5000           50
#
#    Front Camera                  Processor_    Price
# 0             5  Unisoc Spreadtrum SC9863A1   7299.0
# 1             5  Unisoc Spreadtrum SC9863A1   7299.0
# 2            16     Qualcomm Snapdragon 680  11999.0
# 3             5          Mediatek Helio A22   5649.0
# 4             5                         G37   8999.0

# %% [markdown]
# # Feature creation

# %%
def concat_colums(x,y):
    if x>0 and y>0:
        return str(x) + '+' + str(y)
    elif x==0 and y>0 :
        return str(y)
    elif x>0 and y == 0:
        return str(x)
    else:
        return str(0)
concat_colums(0,0)
# Out:
# '0'

# %%
# Apply function in dataset to add new feature
df['Camera quality index (Front + Rear specs in MP)'] = df.apply(lambda x: concat_colums(x['Front Camera'],x['Rear Camera']),axis = 1)

# %%
# Make a feature for Phone Storage by adding both memory columns
df['Phone storage(RAM +ROM in GB)'] = df.apply(lambda x: concat_colums(x['RAM'],x['Memory']),axis = 1)

# %%
#Values counts of phone storage
df['Phone storage(RAM +ROM in GB)'].value_counts()
# Out:
# 4+64     128
# 8+128    112
# 6+128    100
# 4+128     41
# 8+256     40
# 3+32      29
# 2+32      22
# 6+64      15
# 2+64      11
# 3+64       9
# 4+256      8
# 6+256      4
# 2+16       2
# 8+64       2
# 4+16       2
# 2+256      2
# 3+256      1
# 4+32       1
# 8+16       1
# 3+128      1
# Name: Phone storage(RAM +ROM in GB), dtype: int64

# %%
# Values counts of Camara Quality index
df['Camera quality index (Front + Rear specs in MP)'].value_counts()
# Out:
# 8+50      91
# 16+50     82
# 5+8       50
# 5+13      45
# 5+50      38
# 16+64     35
# 16+108    25
# 13+50     25
# 13+48     18
# 8+13      17
# 32+50     12
# 8+64      11
# 16+48     10
# 0          9
# 2          6
# 16+200     6
# 12+12      5
# 32+64      5
# 13+64      4
# 50+64      4
# 2+5        3
# 50+50      3
# 32+108     3
# 8+48       2
# 16+32      2
# 60+108     2
# 60+200     2
# 44+50      2
# 16+40      2
# 8+12       2
# 8+108      1
# 8+16       1
# 8+8        1
# 10+50      1
# 32+48      1
# 32+12      1
# 20+12      1
# 20+64      1
# 10+12      1
# 12+50      1
# Name: Camera quality index (Front + Rear specs in MP), dtype: int64

# %% [markdown]
# Data after feature engineering

# %%
df.iloc[:5,:15]
# Out:
#              Model        Colour  Memory  RAM  Battery_  Rear Camera  \
# 0  Infinix SMART 7   Night Black      64    4      6000           13
# 1  Infinix SMART 7    Azure Blue      64    4      6000           13
# 2     MOTOROLA G32  Mineral Gray     128    8      5000           50
# 3         POCO C50    Royal Blue      32    2      5000            8
# 4  Infinix HOT 30i      Marigold     128    8      5000           50
#
#    Front Camera                  Processor_    Price  \
# 0             5  Unisoc Spreadtrum SC9863A1   7299.0
# 1             5  Unisoc Spreadtrum SC9863A1   7299.0
# 2            16     Qualcomm Snapdragon 680  11999.0
# 3             5          Mediatek Helio A22   5649.0
# 4             5                         G37   8999.0
#
#   Camera quality index (Front + Rear specs in MP)  \
# 0                                            5+13
# 1                                            5+13
# 2                                           16+50
# 3                                             5+8
# 4                                            5+50
#
#   Phone storage(RAM +ROM in GB)
# 0                          4+64
# 1                          4+64
# 2                         8+128
# 3                          2+32
# 4                         8+128

# %% [markdown]
# Save final dataset to system

# %%
df.to_csv('Final_mobile_data.csv')

# %% [markdown]
# # Correlation of standard Mobile data

# %%
correlation_matrix = df.corr(numeric_only=True)
correlation_matrix
# Out:
#                 Memory       RAM  Battery_  Rear Camera  Front Camera  \
# Memory        1.000000  0.624728 -0.070355     0.527890      0.493396
# RAM           0.624728  1.000000 -0.112560     0.437132      0.491954
# Battery_     -0.070355 -0.112560  1.000000     0.191132      0.021995
# Rear Camera   0.527890  0.437132  0.191132     1.000000      0.502209
# Front Camera  0.493396  0.491954  0.021995     0.502209      1.000000
# Price         0.674231  0.649396  0.017919     0.535294      0.649018
#
#                  Price
# Memory        0.674231
# RAM           0.649396
# Battery_      0.017919
# Rear Camera   0.535294
# Front Camera  0.649018
# Price         1.000000

# %% [markdown]
# # Heatmap of dataset

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix,annot= True,cmap='coolwarm',linecolor='black',linewidths=0.2)
plt.title('Heat map of Actual Data\n')
plt.show()

# %% [markdown]
# Convert categorical variables in to numerical variables using one-hot encoding

# %%
categorical_cols = ['Model', 'Colour', 'Processor_','Phone storage(RAM +ROM in GB)','Camera quality index (Front + Rear specs in MP)']
encoded_mobile_data = pd.get_dummies(df,columns=categorical_cols,drop_first=True,dtype=int)

# %%
encoded_mobile_data
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera    Price  \
# 0        64    4      6000           13             5   7299.0
# 1        64    4      6000           13             5   7299.0
# 2       128    8      5000           50            16  11999.0
# 3        32    2      5000            8             5   5649.0
# 4       128    8      5000           50             5   8999.0
# ..      ...  ...       ...          ...           ...      ...
# 536     256    8      3900           50            12  34265.0
# 537      32    2      3100            5             2   5998.0
# 538      64    4      5000           50             8   9990.0
# 539     128    8      5000           50            32  34265.0
# 540     128    4      5000           50             8  15999.0
#
#      Model_APPLE iPhone 12  Model_APPLE iPhone 14 Plus  Model_Google Pixel 6a  \
# 0                        0                           0                      0
# 1                        0                           0                      0
# 2                        0                           0                      0
# 3                        0                           0                      0
# 4                        0                           0                      0
# ..                     ...                         ...                    ...
# 536                      0                           0                      0
# 537                      0                           0                      0
# 538                      0                           0                      0
# 539                      0                           0                      0
# 540                      0                           0                      0
#
#      Model_Google Pixel 7  ...  \
# 0                       0  ...
# 1                       0  ...
# 2                       0  ...
# 3                       0  ...
# 4                       0  ...
# ..                    ...  ...
# 536                     0  ...
# 537                     0  ...
# 538                     0  ...
# 539                     0  ...
# 540                     0  ...
#
#      Camera quality index (Front + Rear specs in MP)_60+108  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_60+200  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+108  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+12  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+13  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+16  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+48  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+50  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  1
# 539                                                  0
# 540                                                  1
#
#      Camera quality index (Front + Rear specs in MP)_8+64  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
#      Camera quality index (Front + Rear specs in MP)_8+8
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 536                                                  0
# 537                                                  0
# 538                                                  0
# 539                                                  0
# 540                                                  0
#
# [531 rows x 646 columns]

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
x = encoded_mobile_data.drop('Price',axis = 1)
y = encoded_mobile_data['Price']

# %% [markdown]
# Split the dataset into training and testing sets

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera  Model_APPLE iPhone 12  \
# 414      64    3      5000           13             8                      0
# 537      32    2      3100            5             2                      0
# 180      32    3      5000           13             5                      0
# 380     256    8      5000           48            13                      0
# 71       32    3      5000            8             5                      0
#
#      Model_APPLE iPhone 14 Plus  Model_Google Pixel 6a  Model_Google Pixel 7  \
# 414                           0                      0                     0
# 537                           0                      0                     0
# 180                           0                      0                     0
# 380                           0                      0                     0
# 71                            0                      0                     0
#
#      Model_Google Pixel 7a  ...  \
# 414                      0  ...
# 537                      0  ...
# 180                      0  ...
# 380                      0  ...
# 71                       0  ...
#
#      Camera quality index (Front + Rear specs in MP)_60+108  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_60+200  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+108  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+12  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+13  \
# 414                                                  1
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+16  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+48  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+50  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+64  \
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
#      Camera quality index (Front + Rear specs in MP)_8+8
# 414                                                  0
# 537                                                  0
# 180                                                  0
# 380                                                  0
# 71                                                   0
#
# [5 rows x 645 columns]

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.78642375, -1.19539368,  0.17014795, ..., -0.46732302,
#         -0.10923907, -0.04862166],
#        [-1.31780809, -1.70173426, -2.21365734, ..., -0.46732302,
#         -0.10923907, -0.04862166],
#        [-1.31780809, -1.19539368,  0.17014795, ..., -0.46732302,
#         -0.10923907, -0.04862166],
#        ...,
#        [-1.31780809, -1.19539368,  0.17014795, ..., -0.46732302,
#         -0.10923907, -0.04862166],
#        [ 0.27634492,  1.33630922,  0.17014795, ..., -0.46732302,
#         -0.10923907, -0.04862166],
#        [ 0.27634492,  0.32362806,  0.17014795, ..., -0.46732302,
#         -0.10923907, -0.04862166]])

# %% [markdown]
# # First Develop Machine learning Model with linear regression

# %%
# Make object of Model
lr_model = LinearRegression()

# %%
# Fit the training dataset in object of model
lr_model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
# Predict the test Data with Model
y_prediction = lr_model.predict(x_test_scaled)

# %%
# Score of model
lr_model.score(x_test_scaled,y_test)
# Out:
# -6.050868324306864e+26

# %% [markdown]
# This model is giving negative score so we will check it with another model

# %%
# Mean Absolute Error
mae1 = mean_absolute_error(y_test, y_prediction)
mae1
# Out:
# 9.817785700079003e+16

# %%
# Root Mean Square Score
rmse1 = mean_squared_error(y_test, y_prediction, squared=False)
rmse1
# Out:
# 1.8291876870330198e+17

# %%
# R2 score
r2_ = r2_score(y_test, y_prediction)
r2_
# Out:
# -6.050868324306864e+26

# %% [markdown]
# # Now Develop Machine learning Model with Random Forest

# %%
# Make object of model
rf_model = RandomForestRegressor()

# %%
# Fit the training dataset in object of model
rf_model.fit(x_train_scaled,y_train)
# Out:
# RandomForestRegressor()

# %%
# Predict the test Data with Model
y_pred = rf_model.predict(x_test_scaled)

# %%
# Score of model
rf_model.score(x_test_scaled,y_test)
# Out:
# 0.8029488869573659

# %% [markdown]
# Evaluate the model

# %%
# Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)

# %%
# Root Mean Square Score
rmse = mean_squared_error(y_test, y_pred, squared=False)

# %%
mae
# Out:
# 1690.3870060080108

# %%
rmse
# Out:
# 3300.9493793441206

# %%
# R2 score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8029488869573659

# %%
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
print("Mean R2 score Error:", r2)
# Out:
# Mean Absolute Error: 1690.3870060080108
# Root Mean Squared Error: 3300.9493793441206
# Mean R2 score Error: 0.8029488869573659

# %% [markdown]
# This model is giving good r2 score

# %% [markdown]
# # Plot of Test target and Predicted target with Random Forest Model

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price')
plt.show()

# %% [markdown]
# This model is giving good results with test data and accuracy is also approx more than 89%.

# %% [markdown]
# # Plot of Test target and Predicted target with Linear Regression Model

# %%
plt.scatter(y_test, y_prediction)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price\n')
plt.show()

# %% [markdown]
# # Feature Importance Analysis:

# %%
# For linear regression, we can analyze the coefficients of the model
feature_importance = pd.DataFrame({'Feature': encoded_mobile_data.drop('Price',axis = 1).columns, 'Coefficient': lr_model.coef_})
print(feature_importance.sort_values(by='Coefficient', ascending=False))
# Out:
#                       Feature   Coefficient
# 478            Processor__G37  3.396078e+16
# 187            Model_vivo Y35  3.260834e+16
# 27      Model_Infinix SMART 7  3.260046e+16
# 286               Colour_Grey  3.034601e+16
# 96   Model_REDMI Note 10 Lite  2.931642e+16
# ..                        ...           ...
# 319         Colour_Magic Blue -3.247584e+16
# 93             Model_REDMI 9i -3.267126e+16
# 16      Model_Infinix HOT 30i -3.738342e+16
# 253     Colour_Deepsea Luster -3.759644e+16
# 76              Model_POCO F1 -4.172444e+16
#
# [645 rows x 2 columns]

# %% [markdown]
# # Top 20 Most important features

# %%
feature_importance.sort_values(by='Coefficient', ascending=False)[0:20]
# Out:
#                                                Feature   Coefficient
# 478                                     Processor__G37  3.396078e+16
# 187                                     Model_vivo Y35  3.260834e+16
# 27                               Model_Infinix SMART 7  3.260046e+16
# 286                                        Colour_Grey  3.034601e+16
# 96                            Model_REDMI Note 10 Lite  2.931642e+16
# 162                              Model_realme Narzo 50  2.898103e+16
# 172                                   Model_redmi mono  2.746191e+16
# 77                                    Model_POCO F5 5G  2.727704e+16
# 220                                 Colour_Blue Marble  2.724287e+16
# 4                                         Front Camera  2.682176e+16
# 138                                    Model_realme 10  2.559489e+16
# 612  Camera quality index (Front + Rear specs in MP...  2.527592e+16
# 481                               Processor__Helio A22  2.517985e+16
# 580                             Processor__Unisoc T612  2.515925e+16
# 62                                     Model_OPPO A17k  2.495767e+16
# 61                                     Model_OPPO A17K  2.436511e+16
# 147                                 Model_realme 9i 5G  2.428358e+16
# 36                                      Model_LAVA Z21  2.413773e+16
# 148                              Model_realme C11 2021  2.381995e+16
# 456                               Colour_Volcanic Grey  2.364706e+16

# %% [markdown]
# # Feature Importance analysis with Random Forest model

# %%
# get the feature importance
feature_importances = rf_model.feature_importances_

# %%
# Create a dataframe to visualize the feature importances
feature_importances_df = pd.DataFrame({'Feature': encoded_mobile_data.drop('Price',axis = 1).columns, "Importance": feature_importances})

# %%
# Sort the data by importance in the descending order
feature_importances_df = feature_importances_df.sort_values(by="Importance", ascending=False)

# %%
# Plot the feature importance(Top 20 features)
plt.figure(figsize=(8,6))
plt.barh(feature_importances_df['Feature'][0:20], feature_importances_df["Importance"][0:20], color='skyblue')
plt.xlabel('Importance')
plt.ylabel("Feature")
plt.title('Feature Importance of top 20 Features\n')
plt.show()

# %%
# Total columns for analysis
df.columns
# Out:
# Index(['Model', 'Colour', 'Memory', 'RAM', 'Battery_', 'Rear Camera',
#        'Front Camera', 'Processor_', 'Price',
#        'Camera quality index (Front + Rear specs in MP)',
#        'Phone storage(RAM +ROM in GB)'],
#       dtype='object')

# %% [markdown]
# # Report and Visualization

# %% [markdown]
# Mobile price variation with memory in phone(Bar Plot)

# %%
sns.barplot(data = df,x="Phone storage(RAM +ROM in GB)",y = 'Price')
plt.xticks(rotation = 75)
plt.title('Mobile price variation with memory in mobile\n')
plt.show()

# %% [markdown]
# Mobile price variation with memory in phone(Scatter Plot)

# %%
sns.scatterplot(data = df,x="Phone storage(RAM +ROM in GB)",y = 'Price')
plt.xticks(rotation = 75)
plt.title('Mobile price variation with memory in mobile\n')
plt.show()

# %% [markdown]
# Insights: When choosing a mobile phone, consider your usage needs. If you require more storage for apps, photos, and videos, opting for a higher memory configuration might be worthwhile. On the other hand, if you prioritize budget, a phone with moderate memory could suffice.

# %% [markdown]
# # Mobile price variation with camera quality index in phone(Bar Plot)

# %%
plt.figure(figsize=(8,6))
sns.barplot(data = df,x="Camera quality index (Front + Rear specs in MP)",y = 'Price')
plt.xticks(rotation = 90)
plt.title('Mobile price variation with Camera quality in mobile\n')
plt.show()

# %% [markdown]
# # Mobile price variation with camera quality index in phone(Scatter Plot)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data = df,x="Camera quality index (Front + Rear specs in MP)",y = 'Price')
plt.xticks(rotation = 90)
plt.title('Mobile price variation with Camera quality in mobile\n')
plt.show()

# %% [markdown]
# Positive Correlation: Generally, as the camera quality (in megapixels) increases, the price of the mobile phone tends to rise. This suggests that consumers are willing to pay more for better camera specifications.

# %% [markdown]
# Mobile price variation with Battery size#

# %%
sns.scatterplot(data = df,x="Battery_",y = 'Price')
plt.xticks(rotation = 90)
plt.title('Mobile price variation with Battery mAH in mobile\n')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(data = df,y = 'Price',x="Processor_")
plt.xticks(rotation = 90)
plt.title('Mobile price variation with Processor in Phone\n')
plt.show()

# %%
plt.figure(figsize=(10,40))
sns.scatterplot(data = df,x = 'Price',y="Colour")
plt.xticks(rotation = 90)
plt.title('Mobile price variation with Colour of Phone\n')
plt.show()
